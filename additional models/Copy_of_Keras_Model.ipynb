# %%
import os, shutil
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from PIL import Image
from keras.utils import plot_model
from IPython.display import Image 

# preprocessing
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# modelling
import keras
import tensorflow as tf
from keras import layers
from keras import models
from keras import utils
from keras import optimizers
from keras.models import Sequential
from keras.losses import binary_crossentropy, categorical_crossentropy
from keras.optimizers import SGD, Adam
from keras.applications.vgg19 import VGG19
from keras import losses
from keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
import math 

# callbacks
from keras.callbacks import History

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
IMAGE_PATH = "/content/gdrive/My Drive/Colab Notebooks/melanoma_classification/siim-isic-melanoma-classification/torch_jpeg/"

train_folder = os.path.join(IMAGE_PATH, 'train')
test_folder = os.path.join(IMAGE_PATH, 'test')

# %%
#train_benign = os.path.join(IMAGE_PATH + 'train' + '/', 'benign')
#test_benign = os.path.join(IMAGE_PATH + 'test' + '/', 'benign')
#files = os.listdir(train_benign)
#for f in files:
#  if np.random.rand(1) < .2:
#    shutil.move(train_benign + '/' + f, test_benign + '/' + f )

#train_malignant = os.path.join(IMAGE_PATH + 'train' + '/', 'malignant')
#test_malignant = os.path.join(IMAGE_PATH + 'test' + '/', 'malignant')
#files = os.listdir(train_malignant)
#for f in files:
#  if np.random.rand(1) < .2:
#    shutil.move(train_malignant + '/' + f, test_malignant + '/' + f )

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.3,
        rotation_range=30,
        horizontal_flip=True,
      #  vertical_flip=True,
        validation_split = 0.2)

# get all the data in the directory /train and reshape them
train_generator = train_datagen.flow_from_directory(
        train_folder, 
        target_size=((64, 64)), 
       # color_mode = 'grayscale', 
        batch_size=2048,
        classes=['benign', 'malignant'])

# get all the data in the directory /train and reshape them
test_generator = train_datagen.flow_from_directory(
        test_folder, 
        target_size=(((64, 64))), 
       # color_mode = 'grayscale', 
        batch_size = 32,
        classes=['benign', 'malignant']
        ) 

# get all the data in the directory /val and reshape them
val_generator = train_datagen.flow_from_directory(
        train_folder,
        target_size=(((64, 64))), 
       # color_mode = 'grayscale', 
        batch_size= 32,
        # class_mode='binary',
        subset='validation',
        classes=['benign', 'malignant'])
# Out:
# Found 9692 images belonging to 2 classes.
# Found 3486 images belonging to 2 classes.
# Found 1937 images belonging to 2 classes.

# %%
training_distribution = { x: len(os.listdir(train_folder +'/' + x)) for x in ['benign', 'malignant']}
test_distribution = { x: len(os.listdir(test_folder +'/' + x)) for x in ['benign', 'malignant']}

print(f"Number of benign images: {training_distribution}")
print(f"Number of benign images: {test_distribution}")
# Out:
# Number of benign images: {'benign': 5380, 'malignant': 4313}
# Number of benign images: {'benign': 2441, 'malignant': 1046}

# %%
train_images, train_labels = next(train_generator)
test_images, test_labels = next(test_generator)
val_images, val_labels = next(val_generator)

# %%
#@title Default title text

#preview training image
array_to_img(train_images[233])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3C6A54F2E8>

# %%
#preview training image
array_to_img(train_images[5])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3C3D577EB8>

# %%
#preview training image
array_to_img(train_images[84])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3C3D577A20>

# %%
# get shape of images in train and test

print(np.shape(train_images))
print(np.shape(train_labels))
print(np.shape(test_images))
print(np.shape(test_labels))
print(np.shape(val_images))
print(np.shape(val_labels))
# Out:
# (2048, 64, 64, 3)
# (2048, 2)
# (32, 64, 64, 3)
# (32, 2)
# (32, 64, 64, 3)
# (32, 2)

# %%
# reshape images to contain dimensions into a single vector
train_img = train_images.reshape(train_images.shape[0], -1)
test_img = test_images.reshape(test_images.shape[0], -1)
val_img = val_images.reshape(val_images.shape[0], -1)

print(train_img.shape)
print(test_img.shape)
print(val_img.shape)
# Out:
# (2048, 12288)
# (32, 12288)
# (32, 12288)

# %%
# reshape images to contain dimensions into a single vector
train_y = np.reshape(train_labels[:,0], (2048,1))
test_y = np.reshape(test_labels[:,0], (32,1))
val_y = np.reshape(val_labels[:,0], (32,1))

# %%
#preview label to identify class valujes
train_labels
# Out:
# array([[1., 0.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [0., 1.],
#        [1., 0.],
#        [1., 0.]], dtype=float32)

# %%
#identify the categorical values of 0 and 1
train_generator.class_indices
# Out:
# {'benign': 0, 'malignant': 1}

# %%
train_labels_final = train_labels.T[[1]]
np.shape(train_labels_final)
# Out:
# (1, 2048)

# %%
test_labels_final = test_labels.T[[1]]
np.shape(test_labels_final)
# Out:
# (1, 32)

# %%
array_to_img(train_images[210])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3C3D578FD0>

# %%
train_labels_final[:,210]
# Out:
# array([0.], dtype=float32)

# %% [markdown]
# ### Base CNN Model

# %%
np.random.seed(123)

# model = models.Sequential()
# model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
 
# model.add(layers.Flatten())
# model.add(layers.Dense(10, activation='softmax'))


base_model = models.Sequential()
base_model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(64, 64,  3)))
base_model.add(layers.MaxPooling2D((2, 2)))

base_model.add(layers.Conv2D(32, (4, 4), activation='relu'))
base_model.add(layers.MaxPooling2D((2, 2)))

base_model.add(layers.Conv2D(64, (3, 3), activation='relu'))
base_model.add(layers.MaxPooling2D((2, 2)))



base_model.add(layers.Flatten())
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(1, activation='sigmoid'))


opt = Adam(learning_rate=.001)

base_model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
 
# model.compile(loss='sparse_categorical_crossentropy',
#               optimizer='sgd',
#               metrics=['accuracy'])

base_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        16416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                147520
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 183,393
# Trainable params: 183,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(base_model, show_shapes=True, show_layer_names=True)

# %%
history = base_model.fit(train_images,
          train_y,
          epochs=10,
          # batch_size=32,
          validation_data=(val_images, val_y))
# Out:
# Epoch 1/10
# 64/64 [==============================] - 11s 169ms/step - loss: 0.6885 - accuracy: 0.5659 - val_loss: 0.7047 - val_accuracy: 0.5625
# Epoch 2/10
# 64/64 [==============================] - 10s 164ms/step - loss: 0.6848 - accuracy: 0.5630 - val_loss: 0.7146 - val_accuracy: 0.5625
# Epoch 3/10
# 64/64 [==============================] - 11s 165ms/step - loss: 0.6856 - accuracy: 0.5596 - val_loss: 0.6915 - val_accuracy: 0.5625
# Epoch 4/10
# 64/64 [==============================] - 10s 164ms/step - loss: 0.6795 - accuracy: 0.5659 - val_loss: 0.7063 - val_accuracy: 0.5625
# Epoch 5/10
# 64/64 [==============================] - 10s 163ms/step - loss: 0.6774 - accuracy: 0.5684 - val_loss: 0.6789 - val_accuracy: 0.5625
# Epoch 6/10
# 64/64 [==============================] - 10s 164ms/step - loss: 0.6772 - accuracy: 0.5630 - val_loss: 0.6731 - val_accuracy: 0.5625
# Epoch 7/10
# 64/64 [==============================] - 10s 163ms/step - loss: 0.6747 - accuracy: 0.5928 - val_loss: 0.6778 - val_accuracy: 0.5625
# Epoch 8/10
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6785 - accuracy: 0.5674 - val_loss: 0.6759 - val_accuracy: 0.5000
# Epoch 9/10
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6746 - accuracy: 0.5889 - val_loss: 0.6539 - val_accuracy: 0.5625
# Epoch 10/10
# 64/64 [==============================] - 10s 161ms/step - loss: 0.6722 - accuracy: 0.5884 - val_loss: 0.6700 - val_accuracy: 0.5312

# %%
results_train = base_model.evaluate(train_images, train_y)
# Out:
# 64/64 [==============================] - 3s 45ms/step - loss: 0.6704 - accuracy: 0.6177

# %%
results_test = base_model.evaluate(test_images, test_y)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6586 - accuracy: 0.5938

# %%
results_train
# Out:
# [0.6703994870185852, 0.61767578125]

# %%
results_test
# Out:
# [0.6585903763771057, 0.59375]

# %%
def visualize_training_results(results):
    history = results.history
    plt.figure()
    plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
    plt.figure()
    plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy', 'accuracy'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

visualize_training_results(history)

# %% [markdown]
# ### Model 2

# %%
np.random.seed(123)

base2_model = models.Sequential()
base2_model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(64, 64,  3)))
base2_model.add(layers.MaxPooling2D((2, 2)))

base2_model.add(layers.Conv2D(32, (4, 4), activation='relu'))
base2_model.add(layers.MaxPooling2D((2, 2)))

base2_model.add(layers.Conv2D(64, (3, 3), activation='relu'))
base2_model.add(layers.MaxPooling2D((2, 2)))
base2_model.add(layers.Flatten())
base2_model.add(layers.Dense(64, activation='relu'))
base2_model.add(layers.Dense(1, activation='sigmoid'))

base2_model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy']) 

base2_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 32)        16416
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                147520
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 183,393
# Trainable params: 183,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(base2_model, show_shapes=True, show_layer_names=True)

# %%
history = base2_model.fit(train_images,
          train_y,
          epochs=40,
          batch_size=32,
          validation_data=(val_images, val_y))
# Out:
# Epoch 1/40
# 64/64 [==============================] - 11s 165ms/step - loss: 0.6889 - accuracy: 0.5566 - val_loss: 0.6859 - val_accuracy: 0.5625
# Epoch 2/40
# 64/64 [==============================] - 10s 161ms/step - loss: 0.6860 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 3/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6848 - accuracy: 0.5659 - val_loss: 0.6857 - val_accuracy: 0.5625
# Epoch 4/40
# 64/64 [==============================] - 10s 163ms/step - loss: 0.6853 - accuracy: 0.5659 - val_loss: 0.6855 - val_accuracy: 0.5625
# Epoch 5/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6848 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 6/40
# 64/64 [==============================] - 10s 161ms/step - loss: 0.6850 - accuracy: 0.5659 - val_loss: 0.6855 - val_accuracy: 0.5625
# Epoch 7/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6848 - accuracy: 0.5659 - val_loss: 0.6854 - val_accuracy: 0.5625
# Epoch 8/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6884 - accuracy: 0.5659 - val_loss: 0.6858 - val_accuracy: 0.5625
# Epoch 9/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6857 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 10/40
# 64/64 [==============================] - 10s 161ms/step - loss: 0.6850 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 11/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6847 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 12/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6848 - accuracy: 0.5659 - val_loss: 0.6854 - val_accuracy: 0.5625
# Epoch 13/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6847 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 14/40
# 64/64 [==============================] - 10s 160ms/step - loss: 0.6845 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 15/40
# 64/64 [==============================] - 10s 159ms/step - loss: 0.6852 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 16/40
# 64/64 [==============================] - 10s 161ms/step - loss: 0.6834 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 17/40
# 64/64 [==============================] - 10s 160ms/step - loss: 0.6827 - accuracy: 0.5659 - val_loss: 0.6767 - val_accuracy: 0.5625
# Epoch 18/40
# 64/64 [==============================] - 10s 160ms/step - loss: 0.6818 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 19/40
# 64/64 [==============================] - 10s 161ms/step - loss: 0.6835 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 20/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6815 - accuracy: 0.5664 - val_loss: 0.6779 - val_accuracy: 0.5625
# Epoch 21/40
# 64/64 [==============================] - 10s 160ms/step - loss: 0.6826 - accuracy: 0.5698 - val_loss: 0.6846 - val_accuracy: 0.5625
# Epoch 22/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6799 - accuracy: 0.5698 - val_loss: 0.6801 - val_accuracy: 0.5938
# Epoch 23/40
# 64/64 [==============================] - 10s 160ms/step - loss: 0.6789 - accuracy: 0.5708 - val_loss: 0.6742 - val_accuracy: 0.5938
# Epoch 24/40
# 64/64 [==============================] - 10s 160ms/step - loss: 0.6756 - accuracy: 0.5698 - val_loss: 0.6758 - val_accuracy: 0.5938
# Epoch 25/40
# 64/64 [==============================] - 10s 161ms/step - loss: 0.6751 - accuracy: 0.5703 - val_loss: 0.6709 - val_accuracy: 0.5938
# Epoch 26/40
# 64/64 [==============================] - 10s 159ms/step - loss: 0.6734 - accuracy: 0.5737 - val_loss: 0.6640 - val_accuracy: 0.5938
# Epoch 27/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6714 - accuracy: 0.5732 - val_loss: 0.6641 - val_accuracy: 0.5938
# Epoch 28/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6698 - accuracy: 0.5776 - val_loss: 0.6657 - val_accuracy: 0.5938
# Epoch 29/40
# 64/64 [==============================] - 10s 160ms/step - loss: 0.6685 - accuracy: 0.5791 - val_loss: 0.5940 - val_accuracy: 0.5938
# Epoch 30/40
# 64/64 [==============================] - 10s 161ms/step - loss: 0.6639 - accuracy: 0.5850 - val_loss: 0.5705 - val_accuracy: 0.5938
# Epoch 31/40
# 64/64 [==============================] - 10s 161ms/step - loss: 0.6617 - accuracy: 0.5820 - val_loss: 0.6334 - val_accuracy: 0.5938
# Epoch 32/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6546 - accuracy: 0.5854 - val_loss: 0.5398 - val_accuracy: 0.5938
# Epoch 33/40
# 64/64 [==============================] - 10s 163ms/step - loss: 0.6556 - accuracy: 0.5879 - val_loss: 0.5097 - val_accuracy: 0.6250
# Epoch 34/40
# 64/64 [==============================] - 10s 161ms/step - loss: 0.6519 - accuracy: 0.5923 - val_loss: 0.5025 - val_accuracy: 0.5938
# Epoch 35/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6428 - accuracy: 0.6113 - val_loss: 0.5793 - val_accuracy: 0.6250
# Epoch 36/40
# 64/64 [==============================] - 10s 163ms/step - loss: 0.6482 - accuracy: 0.6050 - val_loss: 0.6492 - val_accuracy: 0.6250
# Epoch 37/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6447 - accuracy: 0.5962 - val_loss: 0.6267 - val_accuracy: 0.5625
# Epoch 38/40
# 64/64 [==============================] - 10s 162ms/step - loss: 0.6178 - accuracy: 0.6401 - val_loss: 0.5374 - val_accuracy: 0.7500
# Epoch 39/40
# 64/64 [==============================] - 10s 163ms/step - loss: 0.6103 - accuracy: 0.6489 - val_loss: 0.5167 - val_accuracy: 0.7188
# Epoch 40/40
# 64/64 [==============================] - 10s 163ms/step - loss: 0.6007 - accuracy: 0.6724 - val_loss: 0.5707 - val_accuracy: 0.7188

# %%
results_train = base2_model.evaluate(train_images, train_y)
# Out:
# 64/64 [==============================] - 3s 45ms/step - loss: 0.5765 - accuracy: 0.6992

# %%
results_test = base2_model.evaluate(test_images, test_y)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5890 - accuracy: 0.6875

# %%
results_train
# Out:
# [0.576469898223877, 0.69921875]

# %%
results_test
# Out:
# [0.5889801979064941, 0.6875]

# %%
visualize_training_results(history)
